# %%
from IPython.display import Audio
import librosa # pip/pip3 install librosa
import librosa.display
import librosa.feature
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! ls -al /home/nl1115/advml/wvgan_out/20180411005732/319
# Out:
# total 1387
# drwxr-s---   2 nl1115 nl1115    22 Apr 11 09:02 .
# drwxr-s--- 321 nl1115 nl1115   322 Apr 11 09:02 ..
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 10.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 11.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 12.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 13.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 14.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 15.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 16.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 17.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 18.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 19.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 1.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 20.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 2.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 3.wav
# -rw-r-----   1 nl1115 nl1115 65594 Apr 11 09:02 4.wav
# ...

# %%
audio = "/home/nl1115/gc/Gregorian Chant/Voices of Tranquillity 1_3/01 Kyrie - Missa cum jubilo.mp3"

# %%
audio = "/home/nl1115/bach/t/b1.mp3"

# %%
audio = "/home/nl1115/advml/wvgan_out/20180411005732/319/2.wav"

# %%
Audio(audio)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(20, 10))
y, sr = librosa.load(audio)
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=256, fmax=8000)

librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()
